# %% [markdown]
# Recursion is difficult to split up into parallel processes, while the 'plugging values into function' method is easily seperable.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
C = 10E-3 #F
R = 80 #Ohm
Eps = 50 #V
t=np.linspace(0,4,100)

def qdis(t): 
    return C*Eps*np.exp(-t/(R*C))

def qdis_t(t, nn=10):
    
    
plt.plot(qdis(t),t)

# %% [markdown]
# #Homework 1 : Charging capacitor, boundaries are $q(t=0) = 0, q(t\rightarrow\infty = C\epsilon)$
